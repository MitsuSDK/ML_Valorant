# %%
import os
import numpy as np
import pandas as pd

# Set working directory to project root
os.chdir("/Users/mac/Desktop/valorant-ml-project")

df_overview = pd.read_csv("data/raw/detailed_matches_overview.csv")
df_maps     = pd.read_csv("data/raw/detailed_matches_maps.csv")
df_matches  = pd.read_csv("data/raw/matches.csv")
df_player     = pd.read_csv("data/raw/detailed_matches_player_stats.csv")
df_agent = pd.read_csv("data/raw/performance_data.csv")

# %%
df_overview.head()
#df_overview.info()
#df_overview.shape
#df_overview.columns
# Out:
#    match_id                 match_title                    event  \
# 0    542195  Paper Rex vs Xi Lai Gaming  Valorant Champions 2025
# 1    542196         GIANTX vs Sentinels  Valorant Champions 2025
# 2    542207        NRG vs EDward Gaming  Valorant Champions 2025
# 3    542205          Team Liquid vs DRX  Valorant Champions 2025
# 4    542212  Dragon Ranger Gaming vs T1  Valorant Champions 2025
#
#                   date format                       teams  score  maps_played  \
# 0  2025-09-12 09:00:00    Bo3  Paper Rex vs Xi Lai Gaming  2 - 0            2
# 1  2025-09-12 11:25:00    Bo3         GIANTX vs Sentinels  2 - 1            3
# 2  2025-09-13 09:00:00    Bo3        NRG vs EDward Gaming  2 - 0            2
# 3  2025-09-13 11:55:00    Bo3          Team Liquid vs DRX  0 - 2            2
# 4  2025-09-14 09:00:00    Bo3  Dragon Ranger Gaming vs T1  0 - 2            2
#
#          patch                                      pick_ban_info
# 0  Patch 11.05  XLG ban Lotus; PRX ban Abyss; XLG pick Bind; P...
# 1  Patch 11.05  SEN ban Ascent; GX ban Lotus; SEN pick Corrode...
# 2  Patch 11.05  EDG ban Lotus; NRG ban Sunset; EDG pick Abyss;...
# 3  Patch 11.05  DRX ban Sunset; TL ban Haven; DRX pick Abyss; ...
# 4  Patch 11.05  DRG ban Bind; T1 ban Haven; DRG pick Lotus; T1...

# %%
df_maps.head()
#df_maps.info()
#df_maps.shape
#df_maps.columns
# Out:
#    match_id map_name  map_order   score     winner duration      picked_by
# 0    542195     Bind          1  13 - 9  Paper Rex    48:56  Xi Lai Gaming
# 1    542195   Sunset          2  13 - 5  Paper Rex    39:04      Paper Rex
# 2    542196  Corrode          1  6 - 13  Sentinels    41:17      Sentinels
# 3    542196   Sunset          2  13 - 4     GIANTX    38:15         GIANTX
# 4    542196    Haven          3  13 - 9     GIANTX    51:34        Decider

# %%
df_matches.head()
#df_matches.info()
#df_matches.shape
#df_matches.columns
# Out:
#                       date  match_id     time                 team1  score1  \
# 0  Fri, September 12, 2025    542195  6:30 PM             Paper Rex       2
# 1  Fri, September 12, 2025    542196  8:55 PM                GIANTX       2
# 2  Sat, September 13, 2025    542207  6:30 PM                   NRG       2
# 3  Sat, September 13, 2025    542205  9:25 PM           Team Liquid       0
# 4  Sun, September 14, 2025    542212  6:30 PM  Dragon Ranger Gaming       0
#
#            team2  score2 score     winner     status         week        stage
# 0  Xi Lai Gaming       0   2-0  Paper Rex  Completed  Opening (A)  Group Stage
# 1      Sentinels       1   2-1     GIANTX  Completed  Opening (A)  Group Stage
# 2  EDward Gaming       0   2-0        NRG  Completed  Opening (C)  Group Stage
# 3            DRX       2   0-2        DRX  Completed  Opening (C)  Group Stage
# 4             T1       2   0-2         T1  Completed  Opening (D)  Group Stage

# %%
df_matches.head()
