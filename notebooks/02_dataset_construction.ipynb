# %%
import os
import pandas as pd

os.chdir("/Users/mac/Desktop/valorant-ml-project")

df_maps     = pd.read_csv("data/raw/detailed_matches_maps.csv")
df_overview = pd.read_csv("data/raw/detailed_matches_overview.csv")
df_player     = pd.read_csv("data/raw/detailed_matches_player_stats.csv")

# %%
temp = pd.merge(df_overview[['match_id', 'date']],
                df_maps[['match_id', 'map_name', 'winner']],  # Added 'match_id' to df_maps for merging
                on='match_id',
                how='outer')

# Then merge the result with df_player on 'match_id'
output = pd.merge(temp,
                  df_player[['match_id', 'player_name', 'player_team', 'rating', 'k', 'd']],  # Added 'match_id' to df_player
                  on='match_id',
                  how='outer')

# Displaying result
print(output)
# Out:
#       match_id                 date map_name     winner player_name  \
# 0       542195  2025-09-12 09:00:00     Bind  Paper Rex   something
# 1       542195  2025-09-12 09:00:00     Bind  Paper Rex    f0rsakeN
# 2       542195  2025-09-12 09:00:00     Bind  Paper Rex      Jinggg
# 3       542195  2025-09-12 09:00:00     Bind  Paper Rex       d4v41
# 4       542195  2025-09-12 09:00:00     Bind  Paper Rex      PatMen
# ...        ...                  ...      ...        ...         ...
# 3315    542279  2025-10-04 07:00:00     Bind     FNATIC        MaKo
# 3316    542279  2025-10-04 07:00:00     Bind     FNATIC        BeYN
# 3317    542279  2025-10-04 07:00:00     Bind     FNATIC     HYUNMIN
# 3318    542279  2025-10-04 07:00:00     Bind     FNATIC     free1ng
# 3319    542279  2025-10-04 07:00:00     Bind     FNATIC   Flashback
#
#      player_team  rating   k   d
# 0      Paper Rex    1.60  40  23
# 1      Paper Rex    1.36  41  25
# 2      Paper Rex    1.32  39  27
# 3      Paper Rex    0.91  25  25
# 4      Paper Rex    0.66  18  26
# ...          ...     ...  ..  ..
# 3315         DRX    1.04  11  11
# 3316         DRX    0.84   8  11
# 3317         DRX    0.65   9  16
# 3318         DRX    0.64   8  15
# 3319         DRX    0.47   6  14
#
# [3320 rows x 9 columns]
